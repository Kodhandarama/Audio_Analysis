# %% [markdown]
# <a href="https://colab.research.google.com/github/Kodhandarama/Audio_Analysis/blob/master/cqt_stft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import *
import IPython.display as ipd

# %%
path1 = '/content/drive/My Drive/Projects/AA/Music dataset/Ahir_bhairavi.wav'
y,sr = librosa.load(path)
Y = np.fft.fftshift(fft(y))
Y_mag = np.abs(Y[int(len(Y)/2):])
Y_freq = np.linspace(0,sr/2,len(Y_mag))

# %%
plt.plot(Y_freq,Y_mag)

# %%
powerSpectrum, freqenciesFound, time, imageAxis = plt.specgram(y, Fs=sr)

# %%
Y_stft = librosa.stft(y)

# %%
D = librosa.amplitude_to_db(np.abs(Y_stft),ref = np.max)

# %%
import librosa.display
x = librosa.display.specshow(D,y_axis='log')

# %%
#freqs, times, mags = librosa.reassigned_spectrogram(y=y, sr=sr)
C = librosa.amplitude_to_db(np.abs(librosa.cqt(y,sr = sr)), ref = np.max)
librosa.display.specshow(C,sr=sr,x_axis='time',y_axis='cqt_note')
